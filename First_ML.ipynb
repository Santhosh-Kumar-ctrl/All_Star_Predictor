# %%
import pandas as pd

# %%
data_2024 = pd.read_csv('Regular_2024.csv')
data_2023 = pd.read_csv('Regular_2023.csv')
data_2022 = pd.read_csv('Regular_2022.csv')
data_2021 = pd.read_csv('Regular_2021.csv')

# %%
data_2023.head()
# Out:
#    Rk                   Player  Age Team Pos   G  GS    MP    FG   FGA  ...  \
# 0   1              Joel Embiid   29  PHI   C  39  39  33.6  11.5  21.8  ...
# 1   2              Luka Dončić   24  DAL  PG  70  70  37.5  11.5  23.6  ...
# 2   3    Giannis Antetokounmpo   29  MIL  PF  73  73  35.2  11.5  18.8  ...
# 3   4  Shai Gilgeous-Alexander   25  OKC  PG  75  75  34.0  10.6  19.8  ...
# 4   5            Jalen Brunson   27  NYK  PG  77  77  35.4  10.3  21.4  ...
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS                    Awards  \
# 0  8.6  11.0  5.6  1.2  1.7  3.8  2.9  34.7                        AS
# 1  8.4   9.2  9.8  1.4  0.5  4.0  2.1  33.9         MVP-3CPOY-6ASNBA1
# 2  8.8  11.5  6.5  1.2  1.1  3.4  2.9  30.4  MVP-4DPOY-9CPOY-12ASNBA1
# 3  4.7   5.5  6.2  2.0  0.9  2.2  2.5  30.1   MVP-2DPOY-7CPOY-3ASNBA1
# 4  3.1   3.6  6.7  0.9  0.2  2.4  1.9  28.7         MVP-5CPOY-5ASNBA2
#
#    Player-additional
# 0          embiijo01
# 1          doncilu01
# ...

# %%
data_2024 = data_2024.drop_duplicates(subset=['Player'], keep='first')
data_2023 = data_2023.drop_duplicates(subset=['Player'], keep='first')
data_2022 = data_2022.drop_duplicates(subset=['Player'], keep='first')
data_2021 = data_2021.drop_duplicates(subset=['Player'], keep='first')

# %%
data_2024.head()
# Out:
#    Rk                   Player  Age Team Pos   G  GS    MP    FG   FGA  ...  \
# 0   1  Shai Gilgeous-Alexander   26  OKC  PG  76  76  34.2  11.3  21.8  ...
# 1   2    Giannis Antetokounmpo   30  MIL  PF  67  67  34.2  11.8  19.7  ...
# 2   3             Nikola Jokić   29  DEN   C  70  70  36.7  11.2  19.5  ...
# 3   4              Luka Dončić   25  2TM  PG  50  50  35.4   9.2  20.5  ...
# 6   5          Anthony Edwards   23  MIN  SG  79  79  36.3   9.1  20.4  ...
#
#    DRB   TRB   AST  STL  BLK  TOV   PF   PTS                    Awards  \
# 0  4.1   5.0   6.4  1.7  1.0  2.4  2.2  32.7  MVP-1DPOY-10CPOY-8ASNBA1
# 1  9.7  11.9   6.5  0.9  1.2  3.1  2.3  30.4         MVP-3DPOY-8ASNBA1
# 2  9.9  12.7  10.2  1.8  0.6  3.3  2.3  29.6         MVP-2CPOY-2ASNBA1
# 3  7.4   8.2   7.7  1.8  0.4  3.6  2.5  28.2                       NaN
# 6  4.9   5.7   4.5  1.2  0.6  3.2  1.9  27.6         MVP-7CPOY-3ASNBA2
#
#    Player-additional
# 0          gilgesh01
# 1          antetgi01
# ...

# %%
data_2023.head()
# Out:
#    Rk                   Player  Age Team Pos   G  GS    MP    FG   FGA  ...  \
# 0   1              Joel Embiid   29  PHI   C  39  39  33.6  11.5  21.8  ...
# 1   2              Luka Dončić   24  DAL  PG  70  70  37.5  11.5  23.6  ...
# 2   3    Giannis Antetokounmpo   29  MIL  PF  73  73  35.2  11.5  18.8  ...
# 3   4  Shai Gilgeous-Alexander   25  OKC  PG  75  75  34.0  10.6  19.8  ...
# 4   5            Jalen Brunson   27  NYK  PG  77  77  35.4  10.3  21.4  ...
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS                    Awards  \
# 0  8.6  11.0  5.6  1.2  1.7  3.8  2.9  34.7                        AS
# 1  8.4   9.2  9.8  1.4  0.5  4.0  2.1  33.9         MVP-3CPOY-6ASNBA1
# 2  8.8  11.5  6.5  1.2  1.1  3.4  2.9  30.4  MVP-4DPOY-9CPOY-12ASNBA1
# 3  4.7   5.5  6.2  2.0  0.9  2.2  2.5  30.1   MVP-2DPOY-7CPOY-3ASNBA1
# 4  3.1   3.6  6.7  0.9  0.2  2.4  1.9  28.7         MVP-5CPOY-5ASNBA2
#
#    Player-additional
# 0          embiijo01
# 1          doncilu01
# ...

# %%
data_2023.columns
# Out:
# Index(['Rk', 'Player', 'Age', 'Team', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA',
#        'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS',
#        'Awards', 'Player-additional'],
#       dtype='object')

# %%
data_2024['All Star'] = 0
data_2023['All Star'] = 0
data_2022['All Star'] = 0
data_2021['All Star'] = 0

# %%
data_2024.head()
# Out:
#    Rk                   Player  Age Team Pos   G  GS    MP    FG   FGA  ...  \
# 0   1  Shai Gilgeous-Alexander   26  OKC  PG  76  76  34.2  11.3  21.8  ...
# 1   2    Giannis Antetokounmpo   30  MIL  PF  67  67  34.2  11.8  19.7  ...
# 2   3             Nikola Jokić   29  DEN   C  70  70  36.7  11.2  19.5  ...
# 3   4              Luka Dončić   25  2TM  PG  50  50  35.4   9.2  20.5  ...
# 6   5          Anthony Edwards   23  MIN  SG  79  79  36.3   9.1  20.4  ...
#
#     TRB   AST  STL  BLK  TOV   PF   PTS                    Awards  \
# 0   5.0   6.4  1.7  1.0  2.4  2.2  32.7  MVP-1DPOY-10CPOY-8ASNBA1
# 1  11.9   6.5  0.9  1.2  3.1  2.3  30.4         MVP-3DPOY-8ASNBA1
# 2  12.7  10.2  1.8  0.6  3.3  2.3  29.6         MVP-2CPOY-2ASNBA1
# 3   8.2   7.7  1.8  0.4  3.6  2.5  28.2                       NaN
# 6   5.7   4.5  1.2  0.6  3.2  1.9  27.6         MVP-7CPOY-3ASNBA2
#
#    Player-additional  All Star
# 0          gilgesh01         0
# 1          antetgi01         0
# ...

# %%
data_2024.drop(['Team','Pos','Age','3P','3PA','2P','2PA','Awards','Player-additional'], axis=1, inplace=True)
data_2023.drop(['Team','Pos','Age','3P','3PA','2P','2PA','Awards','Player-additional'], axis=1, inplace=True)
data_2022.drop(['Team','Pos','Age','3P','3PA','2P','2PA','Awards','Player-additional'], axis=1, inplace=True)
data_2021.drop(['Team','Pos','Age','3P','3PA','2P','2PA','Awards','Player-additional'], axis=1, inplace=True)

# %%
data_2024.head()
data_2023.head()
data_2022.head()
data_2021.head()
# Out:
#    Rk                 Player   G  GS    MP    FG   FGA    FG%    3P%    2P%  \
# 0   1            Joel Embiid  68  68  33.8   9.8  19.6  0.499  0.371  0.529
# 1   2           LeBron James  56  56  37.2  11.4  21.8  0.524  0.359  0.620
# 2   3  Giannis Antetokounmpo  67  67  32.9  10.3  18.6  0.553  0.293  0.616
# 3   4           Kevin Durant  55  55  37.2  10.5  20.3  0.518  0.383  0.568
# 4   5            Luka Dončić  65  65  35.4   9.9  21.6  0.457  0.353  0.528
#
#    ...  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS  All Star
# 0  ...  2.1  9.6  11.7  4.2  1.1  1.5  3.1  2.7  30.6         0
# 1  ...  1.1  7.1   8.2  6.2  1.3  1.1  3.5  2.2  30.3         0
# 2  ...  2.0  9.6  11.6  5.8  1.1  1.4  3.3  3.2  29.9         0
# 3  ...  0.5  6.9   7.4  6.4  0.9  0.9  3.5  2.1  29.9         0
# 4  ...  0.9  8.3   9.1  8.7  1.2  0.6  4.5  2.2  28.4         0
#
# [5 rows x 24 columns]

# %%
data_2024.at['Giannis Antetokounmpo','All Star'] = 1
data_2024.loc['Shai Gilgeous-Alexander','All Star'] = 1
data_2024.loc['Nikola Jokić','All Star'] = 1
data_2024.loc['Donovan Mitchell','All Star'] = 1
data_2024.loc['Alperen Şengün','All Star'] = 1
data_2024.loc['Pascal Siakam','All Star'] = 1
data_2024.loc['Karl-Anthony Towns','All Star'] = 1
data_2024.loc['Victor Wembanyama','All Star'] = 1
data_2024.loc['Trae Young','All Star'] = 1
data_2024.loc['Jalen Brunson','All Star'] = 1
data_2024.loc['Cade Cunningham','All Star'] = 1
data_2024.loc['Anthony Edwards','All Star'] = 1
data_2024.loc['Darius Garland','All Star'] = 1
data_2024.loc['Tyler Herro','All Star'] = 1
data_2024.loc['Jaren Jackson Jr.','All Star'] = 1
data_2024.loc['Evan Mobley','All Star'] = 1
data_2024.loc['Jalen Williams','All Star'] = 1
data_2024.loc['Jaylen Brown','All Star'] = 1
data_2024.loc['Stephen Curry','All Star'] = 1
data_2024.loc['Anthony Davis','All Star'] = 1
data_2024.loc['Kevin Durant','All Star'] = 1
data_2024.loc['James Harden','All Star'] = 1
data_2024.loc['Kyrie Irving','All Star'] = 1
data_2024.loc['LeBron James','All Star'] = 1
data_2024.loc['Damian Lillard','All Star'] = 1
data_2024.loc['Jayson Tatum','All Star'] = 1

# %%
data_2024.head()
# Out:
#     Rk                   Player     G    GS    MP    FG   FGA    FG%    3P%  \
# 0  1.0  Shai Gilgeous-Alexander  76.0  76.0  34.2  11.3  21.8  0.519  0.375
# 1  2.0    Giannis Antetokounmpo  67.0  67.0  34.2  11.8  19.7  0.601  0.222
# 2  3.0             Nikola Jokić  70.0  70.0  36.7  11.2  19.5  0.576  0.417
# 3  4.0              Luka Dončić  50.0  50.0  35.4   9.2  20.5  0.450  0.368
# 6  5.0          Anthony Edwards  79.0  79.0  36.3   9.1  20.4  0.447  0.395
#
#      2P%  ...  ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS  All Star
# 0  0.571  ...  0.9  4.1   5.0   6.4  1.7  1.0  2.4  2.2  32.7       0.0
# 1  0.620  ...  2.2  9.7  11.9   6.5  0.9  1.2  3.1  2.3  30.4       0.0
# 2  0.627  ...  2.9  9.9  12.7  10.2  1.8  0.6  3.3  2.3  29.6       0.0
# 3  0.522  ...  0.8  7.4   8.2   7.7  1.8  0.4  3.6  2.5  28.2       0.0
# 6  0.501  ...  0.8  4.9   5.7   4.5  1.2  0.6  3.2  1.9  27.6       0.0
#
# [5 rows x 24 columns]
